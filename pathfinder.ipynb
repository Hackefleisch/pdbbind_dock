# %%
pdbbind = 'pdbbind_2020/'

pdb_ids = []
with open('pdbbind_2020/index/INDEX_structure.2020') as file:
    for line in file:
        if line[0] != '#':
            line = line.strip().split()
            pdb_ids.append(line[0])


len(pdb_ids)
# Out:
# 19443

# %%
# %load_ext autoreload
# %autoreload 2

from tqdm import tqdm
import subprocess

from clean_pdb import Cleaner

cleaner = Cleaner()

errors = {}

for pdb in tqdm(pdb_ids):
    path = pdbbind + pdb + '/' + pdb 
    pdbfile, fastaseq, nres, flags = cleaner.apply(path + '_protein.pdb')
    if flags['Successful']:
        with open(path + "_cleaned.pdb", 'w') as file:
            file.write(pdbfile)
    else:
        errors[pdb] = flags
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#  15%|█▍        | 2889/19443 [04:11<24:00, 11.49it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 15
#      13 for pdb in tqdm(pdb_ids):
#      14     path = pdbbind + pdb + '/' + pdb
# ---> 15     pdbfile, fastaseq, nres, flags = cleaner.apply(path + '_protein.pdb')
#      16     if flags['Successful']:
#      17         with open(path + "_cleaned.pdb", 'w') as file:
#
# File ~/Projects/pdbbind_dock/clean_pdb.py:755, in Cleaner.apply(self, filename, chains)
#     753 if not resnum == oldresnum:
#     754     if residue_buffer != []:  # is there a residue in the buffer ?
# --> 755         if not self.check_and_print_pdb(count, residue_buffer, residue_letter):
#     756             # if unsuccessful
#     757             self.shit_stat_misdns = True
#     758         else:
#
# File ~/Projects/pdbbind_dock/clean_pdb.py:618, in Cleaner.check_and_print_pdb(self, count, residue_buffer, residue_letter)
#     616         line_edit = line[0:22] + newnum + line[27:]
#     617         # write the residue line
# --> 618         self.pdbfile = self.pdbfile + line_edit
#     620 # finally print residue letter into fasta strea
#     621     chain = line[21]
#
# KeyboardInterrupt:

# %%
len(errors)
# Out:
# 12805

# %%
errors
# Out:
# {'4tln': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '5tln': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2tpi': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '6rsa': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1rnt': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '4tmn': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tmn': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tlp': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '5tmn': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2tmn': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1p04': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1p01': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1p05': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1p06': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1p03': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1p10': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1p02': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '4fab': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '4sga': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '4er1': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '5apr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '6apr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '3er5': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '4apr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '5er2': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '6abp': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '7abp': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2er9': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '8abp': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1rbp': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '4er2': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '3er3': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '6cpa': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '4er4': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2er6': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '5er1': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2er0': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '5abp': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '5est': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '4est': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '9abp': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1apb': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1bap': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2lpr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '9lpr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '6lpr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '8lpr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1abf': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '5lpr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '7lpr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '3lpr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1rgk': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ppl': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1rgl': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '6rnt': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ppm': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1l83': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1bcd': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1fkb': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1cps': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ind': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1gca': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1pip': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1dbb': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1dmb': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1atr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1pop': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1agm': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1apv': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1apw': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ppk': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tmb': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tet': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1dwc': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1elb': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1elc': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1eed': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1rpf': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1thr': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1dwd': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1hef': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1epp': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2ctc': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1fkh': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ths': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tni': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1gbt': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1iht': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1thl': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tnl': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1lst': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1cbx': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1mfa': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ett': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1hgt': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1pph': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tnh': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ent': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1epq': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tnj': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tnk': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1erb': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1inc': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1tng': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ets': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1epo': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1sps': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1add': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ppc': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1mfd': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1fkg': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1ela': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2sim': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1heg': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '8cpa': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '7cpa': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1acj': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1azm': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2hmb': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1him': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '2dbl': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1dbk': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '1dbj': {'Alternative Positions': False,
#   'Inserted Residue': False,
#   'Modified Residue': False,
#   'Missing backbone': False,
#   'Successful': False},
#  '